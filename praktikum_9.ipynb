# %% [markdown]
# <a href="https://colab.research.google.com/github/pedrotbjs-crypto/pedro/blob/main/praktikum_9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

city_names = ['Jakarta', 'Bandung', 'Makassar', 'Surabaya', 'Medan', 'Yogyakarta', 'Malang']
population = [498044, 964254, 491918, 8398748, 653115, 883305, 744955]
num_airports = [2, 2, 8, 3, 1, 3, 2]

df = pd.DataFrame({
    'City Name': city_names,
    'Population': population,
    'Airports': num_airports,
})

df
# Out:
#     City Name  Population  Airports
# 0     Jakarta      498044         2
# 1     Bandung      964254         2
# 2    Makassar      491918         8
# 3    Surabaya     8398748         3
# 4       Medan      653115         1
# 5  Yogyakarta      883305         3
# 6      Malang      744955         2
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# df['Population'].plot(kind='hist', bins=20, title='Population')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# df['Airports'].plot(kind='hist', bins=20, title='Airports')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# ...

# %%
import numpy as np

# Calculate the absolute difference between each city's population and the average population
df['Population_Difference_from_Average'] = np.abs(df['Population'] - rata_rata_populasi)

# Find the city with the minimum difference
city_closest_to_average = df.loc[df['Population_Difference_from_Average'].idxmin()]

print("Kota dengan populasi paling mendekati rata-rata:")
print(city_closest_to_average[['City Name', 'Population']])
# Out:
# Kota dengan populasi paling mendekati rata-rata:
# City Name     Bandung
# Population     964254
# Name: 1, dtype: object

# %%
# Ringkasan statistik
df.describe()

# Rata-rata populasi
rata_rata_populasi = df['Population'].mean()
print("Rata-rata populasi:", rata_rata_populasi)

# Modus jumlah bandara
modus_airports = df['Airports'].mode()
print("Modus Airports:", modus_airports)
# Out:
# Rata-rata populasi: 1804905.5714285714
# Modus Airports: 0    2
# Name: Airports, dtype: int64

# %%
import matplotlib.pyplot as plt

df['Population'].hist()
plt.title("Distribusi Populasi Kota")
plt.xlabel("Jumlah Penduduk")
plt.ylabel("Frekuensi")
plt.show()

# %%
display(df.head())
# Out:
#   City Name  Population  Airports
# 0   Jakarta      498044         2
# 1   Bandung      964254         2
# 2  Makassar      491918         8
# 3  Surabaya     8398748         3
# 4     Medan      653115         1

# %%
# Korelasi
corr_matrix = df[['Population', 'Airports']].corr()
print("Korelasi:\n", corr_matrix)

# Kovarian
cov_matrix = df[['Population', 'Airports']].cov()
print("Kovarian:\n", cov_matrix)
# Out:
# Korelasi:
#              Population  Airports
# Population    1.000000 -0.026109
# Airports     -0.026109  1.000000
# Kovarian:
#                Population       Airports
# Population  8.486123e+12 -175648.833333
# Airports   -1.756488e+05       5.333333

# %%
# Menambah kolom kategori
df['Kategori_Bandara'] = df['Airports'].apply(lambda x: 'Banyak' if x >= 3 else 'Sedikit')
df

# Rata-rata populasi per kategori
group_mean = df.groupby('Kategori_Bandara')['Population'].mean()
print(group_mean)

# Agregasi lengkap
group_agg = df.groupby('Kategori_Bandara').agg({
    'Population': ['mean', 'max'],
    'Airports': ['mean', 'count']
})
group_agg
# Out:
# Kategori_Bandara
# Banyak     3.257990e+06
# Sedikit    7.150920e+05
# Name: Population, dtype: float64
#                     Population           Airports
#                           mean      max      mean count
# Kategori_Bandara
# Banyak            3.257990e+06  8398748  4.666667     3
# Sedikit           7.150920e+05   964254  1.750000     4

# %%
import pandas as pd

body_measurement_df = pd.DataFrame.from_records((
  (2, 83.82, 8.4),
  (4, 99.31, 16.97),
  (3, 96.52, 14.41),
  (6, 114.3, 20.14),
  (4, 101.6, 16.91),
  (2, 86.36, 12.64),
  (3, 92.71, 14.23),
  (2, 85.09, 11.11),
  (2, 85.85, 14.18),
  (5, 106.68, 20.01),
  (4, 99.06, 13.17),
  (5, 109.22, 15.36),
  (4, 100.84, 14.78),
  (6, 115.06, 20.06),
  (2, 84.07, 10.02),
  (7, 121.67, 28.4),
  (3, 94.49, 14.05),
  (6, 116.59, 17.55),
  (7, 121.92, 22.96),
), columns=("age", "height_cm", "weight_kg"))

body_measurement_df
# Out:
#     age  height_cm  weight_kg
# 0     2      83.82       8.40
# 1     4      99.31      16.97
# 2     3      96.52      14.41
# 3     6     114.30      20.14
# 4     4     101.60      16.91
# 5     2      86.36      12.64
# 6     3      92.71      14.23
# 7     2      85.09      11.11
# 8     2      85.85      14.18
# 9     5     106.68      20.01
# 10    4      99.06      13.17
# 11    5     109.22      15.36
# 12    4     100.84      14.78
# 13    6     115.06      20.06
# 14    2      84.07      10.02
# 15    7     121.67      28.40
# 16    3      94.49      14.05
# 17    6     116.59      17.55
# 18    7     121.92      22.96

# %%
# Ringkasan statistik
body_measurement_df.describe()

# Rata-rata tinggi & berat
mean_height = body_measurement_df['height_cm'].mean()
mean_weight = body_measurement_df['weight_kg'].mean()
print("Rata-rata tinggi:", mean_height)
print("Rata-rata berat:", mean_weight)

# Modus umur
mode_age = body_measurement_df['age'].mode()
print("Modus umur:", mode_age)
# Out:
# Rata-rata tinggi: 100.7978947368421
# Rata-rata berat: 16.071052631578947
# Modus umur: 0    2
# Name: age, dtype: int64

# %%
import matplotlib.pyplot as plt

# Tinggi
body_measurement_df['height_cm'].hist()
plt.title("Distribusi Tinggi Badan (cm)")
plt.show()

# Berat
body_measurement_df['weight_kg'].hist()
plt.title("Distribusi Berat Badan (kg)")
plt.show()

# %%
# Mean
group_mean_age = body_measurement_df.groupby("age").mean()
group_mean_age

# Agg lengkap
group_agg_age = body_measurement_df.groupby("age").agg({
    'height_cm': ['mean', 'min', 'max'],
    'weight_kg': ['mean', 'min', 'max']
})
group_agg_age
# Out:
#       height_cm                 weight_kg
#            mean     min     max      mean    min    max
# age
# 2     85.038000   83.82   86.36   11.2700   8.40  14.18
# 3     94.573333   92.71   96.52   14.2300  14.05  14.41
# 4    100.202500   99.06  101.60   15.4575  13.17  16.97
# 5    107.950000  106.68  109.22   17.6850  15.36  20.01
# 6    115.316667  114.30  116.59   19.2500  17.55  20.14
# 7    121.795000  121.67  121.92   25.6800  22.96  28.40

# %%
# Korelasi
corr_hw = body_measurement_df[['height_cm', 'weight_kg']].corr()
print(corr_hw)

# Kovarian
cov_hw = body_measurement_df[['height_cm', 'weight_kg']].cov()
print(cov_hw)
# Out:
#            height_cm  weight_kg
# height_cm   1.000000   0.888014
# weight_kg   0.888014   1.000000
#             height_cm  weight_kg
# height_cm  166.583840  54.525886
# weight_kg   54.525886  22.632521

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import pandas as pd
pedro_ananda = pd.read_csv('/content/customers.csv')

# %%
pedro_ananda.head()
# Out:
#    customer_id customer_name             gender  age  \
# 0            1       fulan 1             Female   30
# 1            2       fulan 2  Prefer not to say   69
# 2            3       fulan 3  Prefer not to say   59
# 3            4       fulan 4  Prefer not to say   67
# 4            5       fulan 5  Prefer not to say   30
#
#                      home_address  zip_code               city  \
# 0  8606 Victoria TerraceSuite 560      5464      Johnstonhaven
# 1      8327 Kirlin SummitApt. 461      8223    New Zacharyfort
# 2       269 Gemma SummitSuite 109      5661           Aliburgh
# 3       743 Bailey GroveSuite 141      1729  South Justinhaven
# 4         48 Hyatt ManorSuite 375      4032     Griffithsshire
#
#                           state    country
# 0            Northern Territory  Australia
# 1               South Australia  Australia
# 2  Australian Capital Territory  Australia
# 3                    Queensland  Australia
# 4                    Queensland  Australia

# %%
pedro_ananda.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1007 entries, 0 to 1006
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   customer_id    1007 non-null   int64
#  1   customer_name  1007 non-null   object
#  2   gender         989 non-null    object
#  3   age            1007 non-null   int64
#  4   home_address   1007 non-null   object
#  5   zip_code       1007 non-null   int64
#  6   city           1007 non-null   object
#  7   state          1007 non-null   object
#  8   country        1007 non-null   object
# dtypes: int64(3), object(6)
# memory usage: 70.9+ KB

# %%
pedro_ananda.isna().sum()
# Out:
# customer_id       0
# customer_name     0
# gender           18
# age               0
# home_address      0
# zip_code          0
# city              0
# state             0
# country           0
# dtype: int64

# %%
# Replace 'pedro_ananda' with 'pedro_ananda' and use square brackets for column selection
pedro_ananda['gender'] = pedro_ananda['gender'].fillna("Prefer not to say") # Assuming a default value for 'gender'
pedro_ananda.isna().sum()
# Out:
# customer_id      0
# customer_name    0
# gender           0
# age              0
# home_address     0
# zip_code         0
# city             0
# state            0
# country          0
# dtype: int64

# %%
pedro_ananda['gender'] =pedro_ananda['gender'].fillna (88)# pedro_ananda['customer_id'] = pedro_ananda['customer_id'].fillna("") # This line is not needed as 'customer_id' has no missing values

pedro_ananda.isna().sum()
# Out:
# customer_id      0
# customer_name    0
# gender           0
# age              0
# home_address     0
# zip_code         0
# city             0
# state            0
# country          0
# dtype: int64

# %%
pedro_ananda['gender'] =pedro_ananda['gender'].fillna (88)

# %%
pedro_ananda.isna().sum()
# Out:
# customer_id      0
# customer_name    0
# gender           0
# age              0
# home_address     0
# zip_code         0
# city             0
# state            0
# country          0
# dtype: int64

# %%
pedro_ananda.duplicated().sum()
# Out:
# np.int64(7)

# %%
pedro_ananda.head(55)
# Out:
#     customer_id customer_name             gender  age  \
# 0             1       fulan 1             Female   30
# 1             2       fulan 2  Prefer not to say   69
# 2             3       fulan 3  Prefer not to say   59
# 3             4       fulan 4  Prefer not to say   67
# 4             5       fulan 5  Prefer not to say   30
# 5             6       fulan 6  Prefer not to say   40
# 6             7       fulan 7  Prefer not to say   76
# 7             8       fulan 8  Prefer not to say   75
# 8             9       fulan 9               Male   51
# 9            10      fulan 10  Prefer not to say   70
# 10           11      fulan 11  Prefer not to say   39
# 11           12      fulan 12  Prefer not to say   78
# 12           13      fulan 13               Male   42
# 13           14      fulan 14  Prefer not to say   36
# 14           15      fulan 15  Prefer not to say   34
# 15           16      fulan 16               Male   75
# ...

# %% [markdown]
# # Task
# The task is to fix the `NameError: name 'df' is not defined` in cell `7l_m6S-EmPvl` by adding the necessary code to define the `df` DataFrame, and then ensure that the histogram of population distribution is correctly displayed.

# %% [markdown]
# ## Explain the Error
#
# ### Subtask:
# Provide a detailed explanation of the NameError: name 'df' is not defined error, specifically why it occurred in the context of the notebook.

# %% [markdown]
# ## Explain the Error
#
# ### Subtask:
# Provide a detailed explanation of the NameError: name 'df' is not defined error, specifically why it occurred in the context of the notebook.
#
# #### Explanation of `NameError: name 'df' is not defined`
#
# The `NameError: name 'df' is not defined` in cell `7l_m6S-EmPvl` occurred because the variable `df` was referenced before it was assigned a value or defined in the current execution environment. In a Jupyter or Colab notebook, cells are executed independently, but variables persist in the kernel's memory across executions.
#
# The `df` DataFrame is initially defined and populated in cell `Frc6NO9Qh7Ef`. However, if cell `Frc6NO9Qh7Ef` was not executed before cell `7l_m6S-EmPvl`, the kernel would not have `df` in its memory, leading to the `NameError`.
#
# To resolve this error and allow cell `7l_m6S-EmPvl` to execute successfully, cell `Frc6NO9Qh7Ef` must be run first to create and define the `df` DataFrame in the kernel's memory.

# %% [markdown]
# ## Fix the Error
#
# ### Subtask:
# Modify the selected cell (`7l_m6S-EmPvl`) by including the necessary code to define the `df` DataFrame from its original definition in cell `Frc6NO9Qh7Ef`. This will ensure `df` is available when the plotting code is executed.

# %% [markdown]
# **Reasoning**:
# To fix the `NameError` in cell `7l_m6S-EmPvl`, I will insert the original `df` DataFrame definition code at the beginning of that cell.

# %%
import pandas as pd

city_names = ['Jakarta', 'Bandung', 'Makassar', 'Surabaya', 'Medan', 'Yogyakarta', 'Malang']
population = [498044, 964254, 491918, 8398748, 653115, 883305, 744955]
num_airports = [2, 2, 8, 3, 1, 3, 2]

df = pd.DataFrame({
    'City Name': city_names,
    'Population': population,
    'Airports': num_airports,
})

import matplotlib.pyplot as plt

df['Population'].hist()
plt.title("Distribusi Populasi Kota")
plt.xlabel("Jumlah Penduduk")
plt.ylabel("Frekuensi")
plt.show()

# %% [markdown]
# ## Final Task
#
# ### Subtask:
# Confirm that the error has been resolved and the histogram of population distribution is displayed correctly.

# %% [markdown]
# ## Summary:
#
# ### Q&A
# The `NameError` has been resolved, and the histogram of population distribution is now displayed correctly.
#
# ### Data Analysis Key Findings
# *   The initial `NameError: name 'df' is not defined` occurred because the `df` DataFrame, which was defined in a separate cell (`Frc6NO9Qh7Ef`), was not available in the execution environment when cell `7l_m6S-EmPvl` attempted to use it.
# *   The error was fixed by explicitly including the code to define the `df` DataFrame within the target cell `7l_m6S-EmPvl`.
# *   After the fix, the Python code executed without errors, successfully generating and displaying the histogram of population distribution, confirming that the `df` DataFrame was correctly defined and accessible.
#
# ### Insights or Next Steps
# *   To prevent similar `NameError` issues in Jupyter/Colab notebooks, ensure that all necessary variable definitions or DataFrame creations are either executed in prior cells or explicitly included where they are used, especially in standalone plotting cells.
# *   For complex notebooks, consider organizing common data loading and DataFrame initializations into a dedicated "setup" cell at the beginning to streamline execution and minimize dependency issues.

# %% [markdown]
# <a href="https://colab.research.google.com/github/pedrotbjs-crypto/pedro/blob/main/pemrograman_6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# SOAL 1: Fungsi Inisialisasi Sederhana
def sapa_praktikan():
    """Mencetak pesan sambutan dasar."""
    print("Sistem siap. Selamat datang kembali di sesi praktikum.")

# Pemanggilan:
sapa_praktikan()


# MODIFIKASI: Menampilkan Biodata Lengkap
def Biodata():
    """Menampilkan biodata lengkap."""
    print("=== BIODATA MAHASISWA ===")
    print("Nama           : Pedro Ananda H")
    print("Tempat/Tgl Lahir : Batam, 18 April 2005")
    print("Alamat         : Sagulung, Sumber Sari Blok C8 No. 36")

# Pemanggilan:
Biodata()
# Out:
# Sistem siap. Selamat datang kembali di sesi praktikum.
# === BIODATA MAHASISWA ===
# Nama           : Pedro Ananda H
# Tempat/Tgl Lahir : Batam, 18 April 2005
# Alamat         : Sagulung, Sumber Sari Blok C8 No. 36

# %%
# SOAL 2: Menghitung Volume Kubus
def hitung_volume_kubus(sisi):
    """Menghitung volume kubus dari panjang sisinya."""
    return sisi ** 3

# Pemanggilan:
panjang_sisi = 5
print(f"Volume kubus dengan sisi {panjang_sisi} adalah: {hitung_volume_kubus(panjang_sisi)}")
# Out:
# Volume kubus dengan sisi 5 adalah: 125

# %%
def tentukan_predikat(skor):
    """Menentukan predikat (A, B, C, D, E) berdasarkan skor."""

    if not isinstance(skor, (int, float)):   # ✅ Mengecek tipe data
        return "Input harus berupa angka!"

    if skor >= 85:
        return "A"
    elif skor >= 70:        # ✅ Kondisi untuk predikat B
        return "B"
    elif skor >= 60:        # ✅ Kondisi untuk predikat C
        return "C"
    elif skor >= 50:
        return "D"
    else:
        return "E"


# Pemanggilan:
print(f"Skor 75 mendapat predikat: {tentukan_predikat(75)}")
print(f"Skor 48 mendapat predikat: {tentukan_predikat(48)}")
# Out:
# Skor 75 mendapat predikat: B
# Skor 48 mendapat predikat: E

# %%
def hitung_faktorial(n):
    """Menghitung faktorial dari bilangan positif n."""

    # ✅ Tangani kasus khusus
    if n < 0:
        return "Faktorial tidak didefinisikan untuk bilangan negatif."
    elif n == 0:
        return 1

    hasil = 1

    # ✅ Perulangan berjalan selama n lebih besar dari 1
    while n > 1:
        hasil *= n   # Kalikan hasil dengan n
        n -= 1       # Kurangi n satu per satu

    return hasil


# Pemanggilan:
bilangan_n = 4
print(f"Faktorial dari {bilangan_n} adalah: {hitung_faktorial(bilangan_n)}")  # Output: 24
# Out:
# Faktorial dari 4 adalah: 24

# %%
# SOAL 6: Analisis Data Suhu Ekstrem (for dan if/elif)
def analisis_suhu(data_suhu):
    """Menghitung jumlah hari Panas dan Dingin dari data_suhu."""
    panas_count = 0
    dingin_count = 0  # Inisialisasi penghitung dingin

    for suhu in data_suhu:
        if suhu >= 35:       # Jika suhu lebih dari atau sama dengan 35, dianggap panas
            panas_count += 1
        elif suhu <= 15:     # Jika suhu kurang dari atau sama dengan 15, dianggap dingin
            dingin_count += 1

    return panas_count, dingin_count


# Pemanggilan:
suhu_mingguan = [36, 30, 14, 25, 38, 16, 28]
jumlah_panas, jumlah_dingin = analisis_suhu(suhu_mingguan)
print(f"Jumlah hari Panas (>=35°C): {jumlah_panas}")
print(f"Jumlah hari Dingin (<=15°C): {jumlah_dingin}")
# Out:
# Jumlah hari Panas (>=35°C): 2
# Jumlah hari Dingin (<=15°C): 1
